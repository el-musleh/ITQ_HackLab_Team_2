# %% [markdown]
# # ITQ HackLab Team 2 — Robot Test Suite
#
# Run tests one section at a time to identify what's working and what's broken.
#
# **Safety:** Motor and servo tests will make the robot move. Place on blocks or keep clear.
#
# **Order:**
# 1. State Machine (pure logic, no hardware)
# 2. Camera
# 3. Motors (robot will move)
# 4. Servos (arm will move)
# 5. Perception (needs camera)
# 6. Integration
# 7. Summary

# %% [markdown]
# ## 0. Setup

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(".."))

from robot_tests import test_results
test_results.reset()
print('Test suite ready.')
# Out:
# Test suite ready.

# %% [markdown]
# ## 1. State Machine Tests (no hardware required)

# %%
from robot_tests.test_state_machine import run_all as run_state_machine
run_state_machine()
# Out:
# --- State Machine Tests (no hardware) ---

# %% [markdown]
# ## 2. Camera Tests
#
# If camera init fails, the fallback OpenCV capture will be tried automatically.

# %%
from robot_tests.test_camera import run_all as run_camera
camera, source = run_camera()
print(f'Camera source: {source}')
# Out:
# --- Camera Tests ---
#
# Camera source: jetbot

# %% [markdown]
# ## 3. Motor Tests
#
# **WARNING: Robot will drive and spin. Keep clear or place on blocks.**

# %%
from robot_tests.test_motors import run_all as run_motors
robot = run_motors(duration=0.5, speed=0.15, max_speed=0.25)
# Out:
# --- Motor Tests ---
# WARNING: Robot will move. Keep clear or place on blocks.

# %% [markdown]
# ## 4. Servo / Arm Tests
#
# **WARNING: Arm will move. Keep clear of fragile objects.**

# %%
from robot_tests.test_servos import run_all as run_servos
servo = run_servos()
# Out:
# --- Servo Tests ---
# WARNING: Arm will move. Keep clear.
#
# Succeeded to open the port
# Succeeded to change the baudrate

# %% [markdown]
# ## 5. Perception Tests (needs working camera)

# %%
from robot_tests.test_perception import run_all as run_perception
run_perception(camera=camera, source=source if 'source' in dir() else 'jetbot')
# Out:
# --- Perception Tests ---

# %% [markdown]
# ## 6. Integration Tests

# %%
from robot_tests.test_integration import run_all as run_integration
run_integration()
# Out:
# --- Integration Tests ---

# %% [markdown]
# ## 7. Final Summary

# %%
results = test_results.summary()
print()
print('Copy this output and paste it into your next request.')
# Out:
# ============================================================
#   TEST SUMMARY
# ============================================================
#   Total:  38
#   Passed: 38
#   Failed: 0
#   Time:   8.10s
# ------------------------------------------------------------
#   [OK] PASS  — State WANDER->AVOID_BOUNDARY
#          transitioned on yellow detect
#   [OK] PASS  — State WANDER->AVOID_OBSTACLE
#          transitioned on obstacle detect
#   [OK] PASS  — Boundary priority
#          boundary wins over obstacle
#   [OK] PASS  — Turn direction (boundary)
#          more yellow left -> turn right
#   [OK] PASS  — Turn direction (obstacle)
#          more edges left -> turn right
#   [OK] PASS  — Avoid timing (phase 1)
#          reverse phase active
#   [OK] PASS  — Avoid timing (done)
#          avoidance complete -> WANDER
#   [OK] PASS  — Cooldown active
#          cooldown for 0.5s
#   [OK] PASS  — Cooldown expired
#          detection re-enabled
#   [OK] PASS  — Speed clamp logic
#          all cases correct
#   [OK] PASS  — STOPPED state
#          blocks all transitions
#   [OK] PASS  — Camera init (jetbot)
#          resolution 320x240
#   [OK] PASS  — Camera frame read
#          shape (240, 320, 3), dtype uint8
#   [OK] PASS  — Camera frame format
#          BGR 3-channel
#   [OK] PASS  — Camera resolution
#          320x240 matches config
#   [OK] PASS  — Robot init
#          Robot() created, motors accessible
#   [OK] PASS  — Motor stop
#          L=0.0 R=0.0
#   [OK] PASS  — Motor forward
#          drove forward 0.5s @ speed=0.15
#   [OK] PASS  — Motor reverse
#          drove reverse 0.5s @ speed=0.15
#   [OK] PASS  — Motor turn left
#          spun left 0.5s @ speed=0.15
#   [OK] PASS  — Motor turn right
#          spun right 0.5s @ speed=0.15
#   [OK] PASS  — Speed clamp
#          max speed 0.25 accepted
#   [OK] PASS  — Servo library
#          SCSCtrl.TTLServo imported
#   [OK] PASS  — Camera pan/tilt
#          pan=0 tilt=15
#   [OK] PASS  — Arm base servo
#          moved to 10
#   [OK] PASS  — Arm shoulder servo
#          moved to 10
#   [OK] PASS  — Arm elbow servo
#          moved to 10
#   [OK] PASS  — Gripper servo
#          open=0 close=-20
#   [OK] PASS  — Servo home
#          all servos returned to 0
#   [OK] PASS  — Frame available
#          shape (240, 320, 3)
#   [OK] PASS  — Yellow detection
#          11520 pixels — yellow detected
#   [OK] PASS  — Obstacle detection
#          412 edge pixels in front ROI
#   [OK] PASS  — Frame rate
#          ~21377.7 fps over 10 frames
#   [OK] PASS  — Safe stop (None robot)
#          no crash with None robot
#   [OK] PASS  — Safe stop (real robot)
#          motors zeroed
#   [OK] PASS  — Camera->Perception pipeline
#          yellow=11520 edges=412
#   [OK] PASS  — Emergency stop sequence
#          state set to STOPPED
#   [OK] PASS  — Reset to WANDER
#          all globals reset
# ============================================================
#   ALL TESTS PASSED — robot is ready.
# ============================================================
#
# Copy this output and paste it into your next request.

# %% [markdown]
# ---
# ## Quick Re-Test
#
# Run individual modules without running the whole suite again.

# %%
# Example: re-test only motors
# from robot_tests.test_motors import run_all as run_motors
# robot = run_motors()
